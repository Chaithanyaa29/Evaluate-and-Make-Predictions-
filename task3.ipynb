# %%
# Import evaluation metric
from sklearn.metrics import mean_absolute_error
import pandas as pd

# Predict scores for the test dataset
predicted_scores = lr_model.predict(X_test)

# Calculate Mean Absolute Error
error = mean_absolute_error(y_test, predicted_scores)

print("Model Evaluation")
print("-----------------")
print("Mean Absolute Error:", round(error, 2))

# Compare Actual and Predicted Scores
comparison = pd.DataFrame({
    "Actual Score": y_test.values,
    "Predicted Score": predicted_scores.round(2)
})

print("\nComparison of Actual and Predicted Scores")
print(comparison)

# Predict score for a student studying 4.5 hours
study_hours = pd.DataFrame({"Hours Studied": [4.5]})

estimated_score = lr_model.predict(study_hours)

print("\nPredicted Score for 4.5 Study Hours:", round(estimated_score[0], 2))
# Out:
# Model Evaluation
# -----------------
# Mean Absolute Error: 0.5
#
# Comparison of Actual and Predicted Scores
#    Actual Score  Predicted Score
# 0            91            90.47
# 1            49            48.52
#
# Predicted Score for 4.5 Study Hours: 59.01
